# %%
print('hello')
 print('hello')  ##들여쓰기 해서 오류

if a<0:
print(test1)  ##들여쓰기 안해서 오류 ##파이썬에서는 들여쓰기 자체가 문법
# Out:
#   File "<ipython-input-4-6855541c8fb3>", line 2
#     print('hello')  ##들여쓰기 오류
#     ^
# IndentationError: unexpected indent

# %%
n=1
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# 1
# <class 'int'>
# 94374280219136

# %%
n=1.0
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# 1.0
# <class 'float'>
# 140183139697776

# %%
n="hi"
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# hi
# <class 'str'>
# 140183764730928

# %%
n=True
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# True
# <class 'bool'>
# 94374279545088

# %%
n=(1,2,3)
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# (1, 2, 3)
# <class 'tuple'>
# 140183139747712

# %%
n=[1,2,3]
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# [1, 2, 3]
# <class 'list'>
# 140183072850240

# %%
n={'name' : 'john' , 'age' : 15}
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# {'name': 'john', 'age': 15}
# <class 'dict'>
# 140183072480224

# %%
n= { 'apple', 'orange', 'orange', 'banana'}
print(n)
print(type(n)) 
print(id(n)) ##데이터 주소
# Out:
# {'banana', 'orange', 'apple'}
# <class 'set'>
# 140183072273184

# %%
a= "'낮말'은 새가 듣고 '밤말'은 쥐가 듣는다."   ##문장안에 홑따옴표 쓰기
print(a)

b='"시간은 금" 이라는 말이 있다.'  ##문장안에 쌍따옴표 쓰기
print(b)
# Out:
# '낮말'은 새가 듣고 '밤말'은 쥐가 듣는다.
# "시간은 금" 이라는 말이 있다.

# %%
a=1>2
print(a)

b=1<2
print(b)
# Out:
# False
# True

# %%
a,b=10,20
print(a+b)

a,b = "10", "20"    ## ""안의 숫자는 문자로 인식
print(a+b)

a,b = 10.0, 20
print(a+b)

a,b = 10,"20"  ## 문자 20을 정수형으로 변환
print(a+int(b))

a,b = 10, 20
print(str(a)+str(b))  ##숫자를 문자형으로 변환

a,b = 10, 20
print(float(a)+float(b))  ##실수형으로 변환
# Out:
# 30
# 1020
# 30.0
# 30
# 1020
# 30.0

# %%
a,b = "10", 20  ##숫자와 문자열 간에 연산할 수 없다
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-99a3388e1913> in <module>()
#       1 a,b = "10", 20  ##숫자와 문자열 간에 연산할 수 없다
# ----> 2 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = input('이름을 입력하세요 : ')  ## input 값은 문자형으로 입력됨
print(name,'님 안녕하세요')
# Out:
# 이름을 입력하세요 : 이창익
# 이창익 님 안녕하세요

# %%
## f스트링 문장사이 변수값을 출력할 때 사용
name = input('이름을 입력하세요 : ')
print(f'{name}님 안녕하세요')

## print(f'  ') 형식  {  } 안쪽에 변수, 계산식 입력
# Out:
# 이름을 입력하세요 : 이창익
# 이창익님 안녕하세요

# %%
num1 = input('첫번째 숫자를 입력하세요 :')
num2 = input('두번째 숫자를 입력하세요 :')
n1 = int(num1)
n2 = int(num2)
print(f'{n1} + {n2} = {n1 + n2}')
print(f'{num1} + {num2} = {int(num1) + int(num2)}')
# Out:
# 첫번째 숫자를 입력하세요 :3
# 두번째 숫자를 입력하세요 :4
# 3 + 4 = 7
# 3 + 4 = 7

# %%
## 산술연산
x=100
y=3
x+y
x-y
x*y
x/y
x//y ## x와 y의 정수로 내림한 몫
x%y ## x/y의 나머지
x**y ## x의 y 거듭제곱
# Out:
# 1000000

# %%
a = input('화씨온도 : ')
print(f'섭씨온도 : {(int(a)-32)*5/9}')
# Out:
# 화씨온도 : 100
# 섭씨온도 : 37.77777777777778

# %%
a = input('밑변 : ')
b = input('높이 : ')
print(f'삼각형의 넓이 : {int(a)*int(b)/2}')
# Out:
# 밑변 : 10
# 높이 : 8
# 삼각형의 넓이 : 40.0

# %%
a = input('원의 반지름 : ')
print(f'원의 둘레 : {2*3.14*int(a)}, 원의 넓이 : {3.14*int(a)**2}')

a = float(input('원의 반지름 : '))   ## input에서 바로 형변환 가능
print(f'원의 둘레 : {2*3.14*a}, 원의 넓이 : {3.14*a**2}')
# Out:
# 원의 반지름 :3
# 원의 둘레 : 18.84, 원의 넓이 : 28.26
# 원의 반지름 :3
# 원의 둘레 : 18.84, 원의 넓이 : 28.26

# %%
x=10
x += 20   ## x값에 20을 더하고 x에 저장
print(x)

x=3
y=5
x *= x+y  ## x값에 x+y 값을 곱하고 x에 저장
print(x)
# Out:
# 30
# 24

# %%
s = "ha"
print(s*5)
# Out:
# hahahahaha

# %%
name = input('이름을 입력하세요 : ')
a = name + "님 안녕하세요."
print(a)
# Out:
# 이름을 입력하세요 : 이창익
# 이창익님 안녕하세요.

# %%
# error 문자열 연결시 숫자 포함
english = 100
result = '영어점수' + english + '점'
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-f80f50d2aadc> in <module>()
#       1 # error 문자열 연결시 숫자 포함
#       2 english = 100
# ----> 3 result = '영어점수' + english + '점'
#       4 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 문자열 연결시 숫자 포함
english = 100
result = '영어점수' + str(english) + '점'
print(result)
# Out:
# 영어점수100점

# %%
a = input('경기장 : ')
b = input('이긴팀 : ')
c = input('진팀 : ')
d = input('vip : ')
e = input('이긴팀 스코어 : ')
f =  input('진팀 스코어 : ')
print(f'오늘 {a}에서 경기가 열렸습니다.')
print(f'{b}와 {c}은 치열한 공방전을 펼쳤습니다.')
print(f'{d}이(가) 맹활약을 펼쳤습니다.')
print(f'결국 {b}이(가) {c}을(를) {e} : {f}로 이겼습니다.')
# Out:
# 경기장 : 1
# 이긴팀 : 2
# 진팀 : 3
# vip :
# 이긴팀 스코어 : 5
# 진팀 스코어 : 4
# 오늘 1에서 경기가 열렸습니다.
# 2와 3은 치열한 공방전을 펼쳤습니다.
# 이(가) 맹활약을 펼쳤습니다.
# 결국 2이(가) 3을(를) 5 : 4로 이겼습니다.

# %%
매물종류 = input('매물종류 : ')
지역 = input('지역 : ')
평 = input('평 : ')
방개수 = input('방개수 : ')
가격 = input('가격 : ')

print(f'''{지역}에 위치한 아주 좋은 {매물종류}이(가) 매물로 나왔습니다. 
이 {매물종류}는 {평}평으로 {방개수}개의 방을 가지고 있습니다. 
가격은 {가격}만원 입니다.''')   ##print문에서 '''쓰면 엔터로 줄넘기기 가능
# Out:
# 매물종류 : 서울
# 지역 : 전세
# 평 : 30
# 방개수 : 3
# 가격 : 1
# 전세에 위치한 아주 좋은 서울이(가) 매물로 나왔습니다.
# 이 서울는 30평으로 3개의 방을 가지고 있습니다.
# 가격은 1만원 입니다.

# %%
name = input('이름을 입력하세요 : ')
sc1 = float(input('국어성적 : '))
sc2 = float(input('영어성적 : '))
sc3 = float(input('수학성적 : '))

print(f'평균성적은 {(sc1+sc2+sc3)/3}입니다.')
# Out:
# 이름을 입력하세요 : 이창익
# 국어성적 : 5
# 영어성적 : 4
# 수학성적 : 6
# 평균성적은 5.0입니다.

# %%
pr1 = int(input('아메리카노 가격 : '))
pr2 = int(input('카페라떼 가격 : '))
pr3 = int(input('카푸치노 가격 : '))

c1 = int(input('아메리카노 판매량 : '))
c2 = int(input('카페라떼 판매량 : '))
c3 = int(input('카푸치노 판매량 : '))

print(f'총 매출은 {(pr1*c1)+(pr2*c2)+(pr3*c3)}원입니다.')
# Out:
# 아메리카노 가격 : 2000
# 카페라떼 가격 : 3000
# 카푸치노 가격 : 3500
# 아메리카노 판매량 : 10
# 카페라떼 판매량 : 20
# 카푸치노 판매량 : 30
# 총 매출은 185000원입니다.

# %%
print('셀 병합 /n /t /' shift key/' 를 누른 후 /n /t /'병합을 원하는 셀들을 다중 선택 후 shift+M')
# Out:
#   File "<ipython-input-101-1b2e0a676ca6>", line 1
#     print('셀 병합 /n /t /' shift key/' 를 누른 후 /n /t /'병합을 원하는 셀들을 다중 선택 후 shift+M')
#                              ^
# SyntaxError: invalid syntax

# %%
print( '셀 병합 \n \t \'shift key\'를 누른후 \n \t \t병합을 원하는 셀들을 다중선택 후 shift+M')   ## \키(백슬래시) 엔터위
# Out:
# 셀 병합
#  	 'shift key'를 누른후
#  	 	병합을 원하는 셀들을 다중선택 후 shift+M

# %%
##전화번호, 우편번호 등 숫자 0으로 시작하면 오류
print(0022)
# Out:
#   File "<ipython-input-105-eea869308204>", line 2
#     print(0022)
#              ^
# SyntaxError: invalid token

# %%
print('0022')
print('010-1111-2222')
# Out:
# 0022
# 010-1111-2222

# %%
## join : 문자열을 원하는 글자로 더한다
## split : 문자열을 원하는 글자로 나눈다.

print('-'.join('Hello World'))
print('Welcome to python'.split(' '))  ## 스페이스바 친곳마다 나눔
# Out:
# H-e-l-l-o- -W-o-r-l-d
# ['Welcome', 'to', 'python']

# %%
a = 8 ==12
print(a,type(a))
b= 'apple' =='APPLE'
print(b,type(b))
c = 8 != 12
print(c,type(c))
# Out:
# False <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>
